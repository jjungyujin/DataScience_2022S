# %%
import pandas as pd

# %%
# df=pd.read_csv('https://raw.githubusercontent.com/tonyfischetti/InteractiveLogisticRegression/master/circles.csv')
df = pd.read_csv('https://raw.githubusercontent.com/tonyfischetti/InteractiveLogisticRegression/master/moons.csv')

# %%
import matplotlib.pyplot as plt
plt.scatter(df['X1'],df['X2'],c=df['Y'])

# %%
sample=df.sample(30)
X=sample[['X1','X2']]
y=sample['Y']

# %%
plt.scatter(X['X1'],X['X2'],c=y)

# %% [markdown]
# ## 로지스틱회귀

# %%
from sklearn.linear_model import LogisticRegression
reg = LogisticRegression()

# %%
reg.fit(X,y)
# Out:
# LogisticRegression()

# %%
# 의사결정 경계선을 그리기 위한 코드
x1_min = df['X1'].min()
x1_max = df['X1'].max()
x2_min = df['X2'].min()
x2_max = df['X2'].max()

# %%
import numpy as np
x1_grid, x2_grid = np.meshgrid(np.arange(x1_min, x1_max, 0.01), np.arange(x2_min, x2_max, 0.01))
X_bound=np.column_stack((x1_grid.ravel(),x2_grid.ravel()))
y_bound=reg.predict(X_bound)
y_bound=y_bound.reshape(x1_grid.shape)
# Out:
# /Users/jung_yujin/miniconda3/envs/dssa/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(X['X1'],X['X2'],c=y)
cs = plt.contourf(x1_grid, x2_grid, y_bound, cmap='RdBu',alpha=0.3)

# %% [markdown]
# ## 2차항 및 인터렉션 포함

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=2,include_bias=False)
X_temp=poly.fit_transform(X)
reg.fit(X_temp,y)
# Out:
# LogisticRegression()

# %%
X_temp
# X1, X2, X1^2, X2^2, X1*X2
# Out:
# array([[ 1.07619300e+00,  9.16387000e-01,  1.15819137e+00,
#          9.86209275e-01,  8.39765134e-01],
#        [ 3.75903000e-01,  8.02857000e-01,  1.41303065e-01,
#          3.01796355e-01,  6.44579362e-01],
#        [ 1.96549000e-01, -5.54250000e-02,  3.86315094e-02,
#         -1.08937283e-02,  3.07193063e-03],
#        [ 6.20919000e-01, -3.79791000e-01,  3.85540405e-01,
#         -2.35819448e-01,  1.44241204e-01],
#        [ 6.15472000e-01, -3.14899000e-01,  3.78805783e-01,
#         -1.93811517e-01,  9.91613802e-02],
#        [ 9.43038000e-01,  3.57067000e-01,  8.89320669e-01,
#          3.36727750e-01,  1.27496842e-01],
#        [ 3.75988000e-01,  1.73541000e-01,  1.41366976e-01,
#          6.52493335e-02,  3.01164787e-02],
#        [ 1.86302900e+00, -2.43804000e-01,  3.47087705e+00,
#         -4.54213922e-01,  5.94403904e-02],
#        [ 1.71502900e+00, -4.49878000e-01,  2.94132447e+00,
#         -7.71553816e-01,  2.02390215e-01],
#        [ 1.54496600e+00, -2.44150000e-01,  2.38691994e+00,
#         -3.77203449e-01,  5.96092225e-02],
#        [-7.54067000e-01,  8.01317000e-01,  5.68617040e-01,
#         -6.04246706e-01,  6.42108934e-01],
#        [-9.39721000e-01,  3.66737000e-01,  8.83075558e-01,
#         -3.44630460e-01,  1.34496027e-01],
#        [ 2.11521200e+00, -1.12878000e-01,  4.47412180e+00,
#         -2.38760900e-01,  1.27414429e-02],
#        [ 2.24522000e-01,  1.05367500e+00,  5.04101285e-02,
#          2.36573218e-01,  1.11023101e+00],
#        [-1.37981000e-01,  8.25490000e-01,  1.90387564e-02,
#         -1.13901936e-01,  6.81433740e-01],
#        [ 4.69520000e-02,  5.69654000e-01,  2.20449030e-03,
#          2.67463946e-02,  3.24505680e-01],
#        [-1.31388000e-01,  3.73737000e-01,  1.72628065e-02,
#         -4.91045570e-02,  1.39679345e-01],
#        [ 1.59694700e+00,  3.88848000e-01,  2.55023972e+00,
#          6.20969647e-01,  1.51202767e-01],
#        [ 2.85016000e-01, -2.87634000e-01,  8.12341203e-02,
#         -8.19802921e-02,  8.27333180e-02],
#        [-1.86058000e-01,  5.84491000e-01,  3.46175794e-02,
#         -1.08749226e-01,  3.41629729e-01],
#        [ 7.90118000e-01,  1.02114300e+00,  6.24286454e-01,
#          8.06823465e-01,  1.04273303e+00],
#        [ 1.44567300e+00, -5.67148000e-01,  2.08997042e+00,
#         -8.19910551e-01,  3.21656854e-01],
#        [ 1.87633000e-01, -1.45983000e-01,  3.52061427e-02,
#         -2.73912282e-02,  2.13110363e-02],
#        [ 2.04265200e+00,  3.91738000e-01,  4.17242719e+00,
#          8.00184409e-01,  1.53458661e-01],
#        [-4.32420000e-01,  7.15025000e-01,  1.86987056e-01,
#         -3.09191111e-01,  5.11260751e-01],
#        [-1.13156000e-01,  1.16066000e+00,  1.28042803e-02,
#         -1.31335643e-01,  1.34713164e+00],
#        [ 1.72255900e+00, -2.98296000e-01,  2.96720951e+00,
#         -5.13832459e-01,  8.89805036e-02],
#        [ 1.92385500e+00,  4.41890000e-02,  3.70121806e+00,
#          8.50132286e-02,  1.95266772e-03],
#        [-1.96226000e-01,  1.85773000e-01,  3.85046431e-02,
#         -3.64534927e-02,  3.45116075e-02],
#        [-5.82501000e-01,  6.05882000e-01,  3.39307415e-01,
#         -3.52926871e-01,  3.67092998e-01]])

# %%
x1_grid, x2_grid = np.meshgrid(np.arange(x1_min, x1_max, 0.01), np.arange(x2_min, x2_max, 0.01))
X_bound=np.column_stack((x1_grid.ravel(),x2_grid.ravel()))
poly=PolynomialFeatures(degree=2,include_bias=False)
y_bound=reg.predict(poly.fit_transform(X_bound))
y_bound=y_bound.reshape(x1_grid.shape)
plt.scatter(X['X1'],X['X2'],c=y)
plt.contourf(x1_grid, x2_grid, y_bound, cmap='RdBu',alpha=0.3)

# %% [markdown]
# ## 3차항 및 인터렉션 포함

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=3,include_bias=False)
X_temp=poly.fit_transform(X)
reg.fit(X_temp,y)
# Out:
# LogisticRegression()

# %%
x1_grid, x2_grid = np.meshgrid(np.arange(x1_min, x1_max, 0.01), np.arange(x2_min, x2_max, 0.01))
X_bound=np.column_stack((x1_grid.ravel(),x2_grid.ravel()))
y_bound=reg.predict(poly.fit_transform(X_bound))
y_bound=y_bound.reshape(x1_grid.shape)
plt.scatter(X['X1'],X['X2'],c=y)
plt.contourf(x1_grid, x2_grid, y_bound, cmap='RdBu',alpha=0.3)

# %% [markdown]
# ## 5차항 및 인터렉션 포함

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=5,include_bias=False)
X_temp=poly.fit_transform(X)
reg.fit(X_temp,y)
# Out:
# LogisticRegression()

# %%
x1_grid, x2_grid = np.meshgrid(np.arange(x1_min, x1_max, 0.01), np.arange(x2_min, x2_max, 0.01))
X_bound=np.column_stack((x1_grid.ravel(),x2_grid.ravel()))
y_bound=reg.predict(poly.fit_transform(X_bound))
y_bound=y_bound.reshape(x1_grid.shape)
plt.scatter(X['X1'],X['X2'],c=y)
plt.contourf(x1_grid, x2_grid, y_bound, cmap='RdBu',alpha=0.3)

# %% [markdown]
# ## 8차항 및 인터렉션 포함

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=8,include_bias=False)
X_temp=poly.fit_transform(X)
reg.fit(X_temp,y)
# Out:
# LogisticRegression()

# %%
x1_grid, x2_grid = np.meshgrid(np.arange(x1_min, x1_max, 0.01), np.arange(x2_min, x2_max, 0.01))
X_bound=np.column_stack((x1_grid.ravel(),x2_grid.ravel()))
y_bound=reg.predict(poly.fit_transform(X_bound))
y_bound=y_bound.reshape(x1_grid.shape)
plt.scatter(X['X1'],X['X2'],c=y)
plt.contourf(x1_grid, x2_grid, y_bound, cmap='RdBu',alpha=0.3)

# %% [markdown]
# ## 유연성 높은 모델이 반드시 좋은가?

# %%
from sklearn.metrics import accuracy_score

real_X = df[['X1','X2']]
real_y = df['Y']
true_acc = []
train_acc = []

for i in range(1,15): # 1차부터 14차까지
    # 데이터 샘플링
    sample=df.sample(30)
    X=sample[['X1','X2']]
    y=sample['Y']    
    # 모델 학습
    poly = PolynomialFeatures(degree=i,include_bias=False)    
    X_temp = poly.fit_transform(X)
    reg.fit(X_temp,y)
    # 학습된 데이터로 예측, 정확도 계산
    y_pred=reg.predict(X_temp)
    train_acc.append(accuracy_score(y,y_pred))
    # 실제 데이터 전체로 예측, 정확도 계산
    real_X_transformed =  poly.fit_transform(real_X)
    true_acc.append(accuracy_score(real_y,reg.predict(real_X_transformed)))
# Out:
# /Users/jung_yujin/miniconda3/envs/dssa/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
plt.plot(train_acc, label='train')
plt.plot(true_acc, label='real')
plt.legend()

# %% [markdown]
# ## 과제 ROC_AUC에 대하여
# ## 평균과 분산
